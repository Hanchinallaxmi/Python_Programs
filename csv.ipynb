# %%
import csv

field =['Name','Branch','Year','CGPA']
rows=[['A','CS','Final Year',8.0],
      ['B','CS','Final Year',8.0],
      ['C','CS','Final Year',8.0],
      ['D','CS','Final Year',8.0],
      ['E','CS','Final Year',8.0]
]

filename='keonics.csv'

with open(filename,'w') as csvfile:
    writer_object= csv.writer(csvfile)
    writer_object.writerow(field)
    writer_object.writerows(rows)


with open(filename,'r') as csvfile:
      data=csv.reader(csvfile)
      for line in data:
            print(line)
# Out:
# ['Name', 'Branch', 'Year', 'CGPA']
# []
# ['A', 'CS', 'Final Year', '8.0']
# []
# ['B', 'CS', 'Final Year', '8.0']
# []
# ['C', 'CS', 'Final Year', '8.0']
# []
# ['D', 'CS', 'Final Year', '8.0']
# []
# ['E', 'CS', 'Final Year', '8.0']
# []

# %%
import csv


with open("C:/Users/Laxmi/Desktop/salaries.csv","r") as file_object:

    data = csv.reader(file_object)
    
    for line in data:   
        print(line[4])
# Out:
# salary
# 80000
# 30000
# 25500
# 175000
# 120000
# 222200
# 136000
# 219000
# 141000
# 147100
# 90700
# 130000
# 100000
# 213660
# 130760
# 147100
# 90700
# 170000
# 150000
# 150000
# 110000
# 275000
# 174000
# 230000
# 143200
# 225000
# 156400
# 200000
# 130000
# 90000
# 72000
# 253200
# 90700
# 342810
# 184590
# 162500
# 130000
# 105380
# 64500
# 100000
# 30000
# 1650000
# 204620
# 110680
# 270703
# 221484
# 212750
# 185000
# 262000
# 245000
# 275300
# 183500
# 218500
# 199098
# 203300
# 123600
# 189110
# 139000
# 258750
# 185000
# 231500
# 166000
# 172500
# 110500
# 238000
# 176000
# 237000
# 201450
# 309400
# 159100
# 115000
# 81500
# 237000
# 201450
# 280000
# 210000
# 280100
# 168100
# 193500
# 139000
# 510000
# 150000
# 65000
# 300000
# 90000
# 185900
# 129300
# 225000
# 175000
# 185000
# 140000
# 45000
# 36000
# 105000
# 70000
# 163196
# 145885
# 217000
# 185000
# 202800
# 104300
# 145000
# 65000
# 165000
# 132300
# 179170
# 94300
# 152500
# 116450
# 247300
# 133800
# 203000
# ...

# %%
import csv


with open("C:/Users/Laxmi/Desktop/Webscraped_NYS.csv","r") as file_object:

    data = csv.reader(file_object)
    
    for line in data:   
        print(line)
# Out:
# ['site_name', 'website', 'latitude', 'longitude', 'address', 'phone', 'description', 'amenities']
# ...

# %%
import csv


with open("C:/Users/Laxmi/Desktop/choclate protfolio project - 11.csv","r") as file_object:

    data = csv.reader(file_object)
    
    for line in data:   
        print(line)
# Out:
# ['Sales Person', 'Geography', 'Product', 'Amount', 'Units', 'cost per unit', 'Cost', 'Profit', 'profit %']
# ['Ram Mahesh', 'New Zealand', '70% Dark Bites', '$1,624 ', '114', '14', '1,652', '($28)', '-2%']
# ['Brien Boise', 'USA', 'Choco Coated Almonds', '$6,706 ', '459', '9', '3,970', '$2,736 ', '41%']
# ['Husein Augar', 'USA', 'Almond Choco', '$959 ', '147', '12', '1,746', '($787)', '-82%']
# ['Carla Molina', 'Canada', 'Drinking Coco', '$9,632 ', '288', '6', '1,863', '$7,769 ', '81%']
# ['Curtice Advani', 'UK', 'White Choc', '$2,100 ', '414', '13', '5,444', '($3,344)', '-159%']
# ['Ram Mahesh', 'USA', 'Peanut Butter Cubes', '$8,869 ', '432', '12', '5,344', '$3,525 ', '40%']
# ['Curtice Advani', 'Australia', 'Smooth Sliky Salty', '$2,681 ', '54', '6', '313', '$2,368 ', '88%']
# ['Brien Boise', 'USA', 'After Nines', '$5,012 ', '210', '10', '2,052', '$2,960 ', '59%']
# ['Ches Bonnell', 'Australia', '50% Dark Bites', '$1,281 ', '75', '12', '878', '$404 ', '31%']
# ...

# %%
import csv


with open("C:/Users/Laxmi/Desktop/choclate protfolio project - 11.csv","r") as file_object:

    data = csv.reader(file_object)
    
    for line in data:   
        print(line[2])
# Out:
# Product
# 70% Dark Bites
# Choco Coated Almonds
# Almond Choco
# Drinking Coco
# White Choc
# Peanut Butter Cubes
# Smooth Sliky Salty
# After Nines
# 50% Dark Bites
# 50% Dark Bites
# White Choc
# Eclairs
# Mint Chip Choco
# Milk Bars
# White Choc
# Manuka Honey Choco
# Smooth Sliky Salty
# Orange Choco
# After Nines
# Orange Choco
# Fruit & Nut Bars
# Fruit & Nut Bars
# After Nines
# 99% Dark & Pure
# Raspberry Choco
# Milk Bars
# Mint Chip Choco
# Orange Choco
# Fruit & Nut Bars
# Fruit & Nut Bars
# 85% Dark Bars
# 99% Dark & Pure
# 70% Dark Bites
# After Nines
# 50% Dark Bites
# Organic Choco Syrup
# Caramel Stuffed Bars
# Mint Chip Choco
# Choco Coated Almonds
# Organic Choco Syrup
# Organic Choco Syrup
# Fruit & Nut Bars
# Raspberry Choco
# 50% Dark Bites
# 99% Dark & Pure
# Fruit & Nut Bars
# Choco Coated Almonds
# Mint Chip Choco
# Manuka Honey Choco
# Eclairs
# Mint Chip Choco
# Spicy Special Slims
# Manuka Honey Choco
# Caramel Stuffed Bars
# Milk Bars
# White Choc
# ...

# %%
import csv


with open("C:/Users/Laxmi/Desktop/choclate protfolio project - 11.csv","r") as file_object:

    data = csv.reader(file_object)
    
    for line in data:   
        print(line[4])
# Out:
# Units
# 114
# 459
# 147
# 288
# 414
# 432
# 54
# 210
# 75
# 12
# 462
# 144
# 120
# 54
# 234
# 66
# 87
# 339
# 144
# 162
# 90
# 234
# 141
# 204
# 186
# 231
# 168
# 195
# 15
# 30
# 102
# 15
# 183
# 12
# 72
# 282
# 144
# 405
# 75
# 135
# 21
# 153
# 15
# 255
# 18
# 189
# 21
# 36
# 75
# 156
# 39
# 63
# 75
# 183
# 69
# 30
# 39
# 504
# 273
# 48
# 207
# 9
# 261
# 6
# 30
# 138
# 111
# 15
# 162
# 195
# 525
# 48
# 150
# 492
# 102
# 165
# 309
# 156
# 159
# 201
# 210
# 51
# 39
# 279
# 123
# 81
# 21
# 162
# 228
# 342
# 54
# 216
# 54
# 75
# 93
# 156
# 9
# 18
# 234
# 312
# 300
# 519
# 9
# 9
# 90
# 96
# 21
# 48
# 72
# 168
# 51
# 192
# 225
# 456
# 93
# 48
# 102
# 252
# 138
# 90
# 240
# 102
# 129
# 300
# 135
# 114
# 63
# 252
# 303
# 246
# 84
# 39
# 348
# 48
# 75
# 258
# 27
# 213
# 357
# 207
# 150
# 204
# 21
# 174
# 201
# 510
# 378
# 27
# 117
# 36
# 126
# 72
# 42
# 135
# 189
# 459
# 201
# 366
# 324
# 243
# 213
# 447
# 297
# 27
# 75
# 30
# 177
# 159
# 306
# 18
# 240
# 93
# 9
# 219
# 141
# 123
# 51
# 120
# ...
